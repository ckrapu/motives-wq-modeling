# %% [markdown]
# ### Imports

# %%
import numpy as np
import scipy
import arviz as az
import os
import boto3
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

from dotenv import load_dotenv
from pathlib import Path

load_dotenv()

bucket_name = "duke-research"
bucket_prefix = ""
file_name_inputs = "inputs.npz"
file_name_gpkg = "final.gpkg"
file_name_trace = "trace-revised.nc"

DATA_DIR = Path("data")
VISUALS_DIR = Path("visuals")
TRACE_PATH = DATA_DIR / file_name_trace
SAVE_FIGURES = False

pd.set_option("display.precision", 3)

# %% [markdown]
# ### Load data

# %% [markdown]
# #### Retrieve from S3

# %%
OVERWRITE = True

files_to_download = [
    file_name_inputs,
    file_name_gpkg,
    file_name_trace
]

for fn in files_to_download:
    if os.path.exists(DATA_DIR / fn) and not OVERWRITE:
        print(f"✓ {fn} already exists")
        continue

    print(f"Downloading {fn} from S3...")
    s3 = boto3.client('s3')
    s3.download_file(bucket_name, fn, DATA_DIR / fn)
    print(f"✓ Successfully downloaded {fn}")
# Out:
# Downloading inputs.npz from S3...
# ✓ Successfully downloaded inputs.npz
# Downloading final.gpkg from S3...
# ✓ Successfully downloaded final.gpkg
# Downloading trace-revised.nc from S3...
# ✓ Successfully downloaded trace-revised.nc

# %%
final_gdf = gpd.read_file(DATA_DIR / file_name_gpkg)
loaded_data = np.load(DATA_DIR /  file_name_inputs)
W = scipy.sparse.csr_matrix((loaded_data['W_data'], loaded_data['W_indices'], loaded_data['W_indptr']))
X = loaded_data['X']
Z = loaded_data['Z']
y = loaded_data['y']
coords = loaded_data['coords']
pretty_predictor_cols = loaded_data['pretty_predictor_cols']

# %% [markdown]
# ### Analyze trace (run after downloading trace, if trace created remotely)

# %%
trace = az.from_netcdf(TRACE_PATH)
final_gdf = gpd.read_file(DATA_DIR / 'final.gpkg')

is_used = final_gdf.huc12.isin(trace.posterior['obs_id'].values)
final_gdf_subset = final_gdf.loc[is_used]
print(f"Trace loaded from disk; {is_used.mean():.2%} of the data used in the model")
# Out:
# Trace loaded from disk; 100.00% of the data used in the model

# %% [markdown]
# ### Report on high-level parameters

# %%
az.summary(trace, varnames=[
    'sigma_factor',
    'beta_scales',
    "sigma"])

# %% [markdown]
# ### Forest plot for coefficients

# %% [markdown]
# #### NLCD coefficients

# %%
col_groups = {
    'nlcd': [
        'Open Water (%)', 'Perennial Ice/Snow (%)',
        'Developed, Open Space (%)', 'Developed, Low Intensity (%)',
        'Developed, Medium Intensity (%)', 'Developed, High Intensity (%)',
        'Barren Land (%)', 'Deciduous Forest (%)', 'Evergreen Forest (%)',
        'Mixed Forest (%)', 'Shrub/Scrub (%)', 'Grassland/Herbaceous (%)',
        'Woody Wetlands (%)', 'Emergent Herbaceous Wetlands (%)'
    ],
    'litho': [
        "Carbonate (%)",
        "Non-carbonate (%)",
        "Alkaline intrusive (%)",
        "Silicic residual (%)",
        "Extrusive volcanic (%)",
        "Colluvial sediment (%)",
        "Glacial till clay (%)",
        "Glacial till loam (%)",
        "Glacial till coarse (%)",
        "Glacial lake sediment fine (%)",
        "Glacial outwash coarse (%)",
        "Hydric (%)",
        "Eolian sediment coarse (%)",
        "Eolian sediment fine (%)",
        "Saline lake sediment (%)",
        "Alluvium and coastal sediment fine (%)",
        "Coastal sediment coarse (%)"
        ],
    'cdl':[
        'Corn (%)', 'Cotton (%)',
        'Rice (%)', 'Sorghum (%)', 'Soybeans (%)', 'Sunflower (%)',
        'Barley (%)', 'Durum Wheat (%)', 'Spring Wheat (%)', 'Winter Wheat (%)',
        'Other Small Grains (%)', 'Double Crop Winter Wheat/Soybeans (%)',
        'Oats (%)', 'Canola (%)', 'Flaxseed (%)', 'Alfalfa (%)',
        'Sugarbeets (%)', 'Dry Beans (%)', 'Potatoes (%)', 'Other Crops (%)',
        'Lentils (%)', 'Peas (%)'
        ],
    'litho_indicators': [
        'Carbonate (Indicator)',
        'Non-carbonate (Indicator)',
        'Alkaline intrusive (Indicator)',
        'Silicic residual (Indicator)',
        'Extrusive volcanic (Indicator)',
        'Colluvial sediment (Indicator)',
        'Glacial till clay (Indicator)',
        'Glacial till loam (Indicator)',
        'Glacial till coarse (Indicator)',
        'Glacial lake sediment fine (Indicator)',
        'Glacial outwash coarse (Indicator)',
        'Hydric (Indicator)',
        'Eolian sediment coarse (Indicator)',
        'Eolian sediment fine (Indicator)',
        'Saline lake sediment (Indicator)',
        'Alluvium and coastal sediment fine (Indicator)',
        'Coastal sediment coarse (Indicator)'
        ],
    "nlcd_indicators": [
         'Grassland/Herbaceous (Indicator)',
       'Emergent Herbaceous Wetlands (Indicator)',
       'Deciduous Forest (Indicator)', 'Shrub/Scrub (Indicator)',
       'Barren Land (Indicator)', 'Evergreen Forest (Indicator)',
       'Developed, Open Space (Indicator)', 'Mixed Forest (Indicator)',
       'Open Water (Indicator)', 'Developed, Low Intensity (Indicator)',
       'Developed, Medium Intensity (Indicator)',
       'Developed, High Intensity (Indicator)', 'Woody Wetlands (Indicator)'
    ],
    'cdl_indicators': [
        'Corn (Indicator)', 'Cotton (Indicator)',
        'Rice (Indicator)', 'Sorghum (Indicator)', 'Soybeans (Indicator)',
        'Sunflower (Indicator)', 'Barley (Indicator)',
        'Durum Wheat (Indicator)', 'Spring Wheat (Indicator)',
        'Winter Wheat (Indicator)', 'Other Small Grains (Indicator)',
        'Double Crop Winter Wheat/Soybeans (Indicator)', 'Oats (Indicator)',
        'Canola (Indicator)', 'Flaxseed (Indicator)', 'Alfalfa (Indicator)',
        'Sugarbeets (Indicator)', 'Dry Beans (Indicator)',
        'Potatoes (Indicator)', 'Other Crops (Indicator)',
        'Lentils (Indicator)', 'Peas (Indicator)'
    ]

}

for col_group, cols in col_groups.items():
    draws = trace.posterior.u.loc[:, :, 'global_mean', cols]
    mean_df = pd.DataFrame(index=cols) \
    .assign(mean=draws.mean(dim=('chain', 'draw'))) \
    .assign(lower_5=draws.quantile(0.05, dim=('chain', 'draw'))) \
    .assign(upper_95=draws.quantile(0.95, dim=('chain', 'draw'))) \
    .assign(significant=lambda df: ~((df['lower_5'] <= 0) & (df['upper_95'] >= 0))) \
    .sort_values(['significant', 'mean'], ascending=[False, False])

    print(mean_df)
# Out:
#                                    mean  lower_5   upper_95  significant
# Grassland/Herbaceous (%)         -0.052   -0.097 -6.884e-04         True
# Shrub/Scrub (%)                  -0.078   -0.116 -3.933e-02         True
# Evergreen Forest (%)             -0.119   -0.180 -4.319e-02         True
# Open Water (%)                   -0.248   -0.325 -1.891e-01         True
# Developed, High Intensity (%)     0.560   -0.185  9.758e-01        False
# Developed, Low Intensity (%)      0.211   -0.040  4.295e-01        False
# Perennial Ice/Snow (%)            0.154   -0.118  4.677e-01        False
# Deciduous Forest (%)              0.113   -0.065  3.784e-01        False
# Emergent Herbaceous Wetlands (%) -0.048   -0.146  4.799e-02        False
# Woody Wetlands (%)               -0.070   -0.162  3.705e-02        False
# Mixed Forest (%)                 -0.071   -0.257  5.348e-02        False
# Developed, Medium Intensity (%)  -0.088   -0.241  6.062e-02        False
# Barren Land (%)                  -0.121   -0.311  8.101e-02        False
# Developed, Open Space (%)        -0.389   -0.863  1.580e-01        False
#                                          mean  lower_5  upper_95  significant
# Carbonate (%)                           0.055    0.019     0.097         True
# Hydric (%)                              0.324   -0.026     0.730        False
# Colluvial sediment (%)                  0.041   -0.082     0.148        False
# Non-carbonate (%)                       0.036   -0.009     0.084        False
# Alkaline intrusive (%)                  0.032   -0.076     0.148        False
# Eolian sediment fine (%)                0.029   -0.029     0.090        False
# Coastal sediment coarse (%)             0.025   -0.348     0.278        False
# Alluvium and coastal sediment fine (%)  0.013   -0.012     0.044        False
# Saline lake sediment (%)                0.013   -0.159     0.234        False
# Eolian sediment coarse (%)              0.006   -0.022     0.041        False
# Silicic residual (%)                    0.006   -0.017     0.037        False
# Glacial lake sediment fine (%)          0.002   -0.051     0.043        False
# Glacial till coarse (%)                -0.003   -0.077     0.068        False
# Glacial till loam (%)                  -0.012   -0.067     0.037        False
# Extrusive volcanic (%)                 -0.013   -0.098     0.065        False
# Glacial outwash coarse (%)             -0.021   -0.129     0.050        False
# Glacial till clay (%)                  -0.032   -0.212     0.174        False
#                                         mean  lower_5  upper_95  significant
# Other Crops (%)                        1.218    0.451     2.198         True
# Double Crop Winter Wheat/Soybeans (%)  0.548   -0.181     0.865        False
# Rice (%)                               0.416   -0.463     2.333        False
# Sugarbeets (%)                         0.383   -0.250     1.057        False
# Durum Wheat (%)                        0.216   -0.209     0.749        False
# Other Small Grains (%)                 0.156   -0.176     0.535        False
# Winter Wheat (%)                       0.074   -0.121     0.275        False
# Corn (%)                              -0.010   -0.226     0.268        False
# Oats (%)                              -0.013   -0.725     0.652        False
# Sunflower (%)                         -0.039   -0.227     0.253        False
# Peas (%)                              -0.046   -0.285     0.163        False
# Potatoes (%)                          -0.047   -0.403     0.333        False
# Alfalfa (%)                           -0.055   -0.451     0.309        False
# Spring Wheat (%)                      -0.056   -0.275     0.080        False
# Flaxseed (%)                          -0.070   -0.311     0.175        False
# Dry Beans (%)                         -0.070   -1.005     0.368        False
# Soybeans (%)                          -0.078   -0.378     0.276        False
# Barley (%)                            -0.078   -0.377     0.355        False
# Canola (%)                            -0.147   -0.401     0.078        False
# Sorghum (%)                           -0.545   -1.330     0.071        False
# Lentils (%)                           -0.622   -1.762     0.401        False
# Cotton (%)                            -0.833   -1.811     0.269        False
#                                                  mean  lower_5  upper_95  \
# Glacial outwash coarse (Indicator)              0.040    0.001     0.078
# Silicic residual (Indicator)                   -0.080   -0.132    -0.048
# Glacial till clay (Indicator)                   0.031   -0.037     0.108
# Saline lake sediment (Indicator)                0.011   -0.018     0.047
# Hydric (Indicator)                              0.009   -0.021     0.036
# Glacial lake sediment fine (Indicator)          0.005   -0.017     0.024
# Eolian sediment coarse (Indicator)              0.004   -0.014     0.028
# Colluvial sediment (Indicator)                  0.002   -0.024     0.025
# Non-carbonate (Indicator)                      -0.001   -0.011     0.006
# Alluvium and coastal sediment fine (Indicator) -0.006   -0.013     0.002
# Carbonate (Indicator)                          -0.008   -0.053     0.040
# Glacial till coarse (Indicator)                -0.009   -0.026     0.010
# Eolian sediment fine (Indicator)               -0.014   -0.031     0.003
# Glacial till loam (Indicator)                  -0.014   -0.038     0.027
# Extrusive volcanic (Indicator)                 -0.015   -0.037     0.006
# Alkaline intrusive (Indicator)                 -0.018   -0.104     0.037
# Coastal sediment coarse (Indicator)            -0.386   -1.062     0.222
#
#                                                 significant
# Glacial outwash coarse (Indicator)                     True
# Silicic residual (Indicator)                           True
# Glacial till clay (Indicator)                         False
# Saline lake sediment (Indicator)                      False
# Hydric (Indicator)                                    False
# Glacial lake sediment fine (Indicator)                False
# Eolian sediment coarse (Indicator)                    False
# Colluvial sediment (Indicator)                        False
# Non-carbonate (Indicator)                             False
# Alluvium and coastal sediment fine (Indicator)        False
# Carbonate (Indicator)                                 False
# Glacial till coarse (Indicator)                       False
# Eolian sediment fine (Indicator)                      False
# Glacial till loam (Indicator)                         False
# Extrusive volcanic (Indicator)                        False
# Alkaline intrusive (Indicator)                        False
# Coastal sediment coarse (Indicator)                   False
#                                                mean  lower_5  upper_95  \
# Developed, Medium Intensity (Indicator)  -7.715e-03   -0.013    -0.003
# Shrub/Scrub (Indicator)                  -1.625e-02   -0.033    -0.001
# Grassland/Herbaceous (Indicator)          6.025e-03   -0.005     0.022
# Deciduous Forest (Indicator)              3.139e-03   -0.006     0.013
# Barren Land (Indicator)                   1.566e-03   -0.008     0.009
# Open Water (Indicator)                    1.232e-03   -0.006     0.009
# Woody Wetlands (Indicator)                1.210e-03   -0.006     0.010
# Evergreen Forest (Indicator)              1.103e-04   -0.011     0.010
# Developed, High Intensity (Indicator)    -1.270e-03   -0.006     0.003
# Developed, Low Intensity (Indicator)     -2.609e-03   -0.009     0.005
# Developed, Open Space (Indicator)        -2.777e-03   -0.010     0.002
# Mixed Forest (Indicator)                 -4.007e-03   -0.015     0.015
# Emergent Herbaceous Wetlands (Indicator) -5.643e-03   -0.014     0.005
#
#                                           significant
# Developed, Medium Intensity (Indicator)          True
# Shrub/Scrub (Indicator)                          True
# Grassland/Herbaceous (Indicator)                False
# Deciduous Forest (Indicator)                    False
# Barren Land (Indicator)                         False
# Open Water (Indicator)                          False
# Woody Wetlands (Indicator)                      False
# Evergreen Forest (Indicator)                    False
# Developed, High Intensity (Indicator)           False
# Developed, Low Intensity (Indicator)            False
# Developed, Open Space (Indicator)               False
# Mixed Forest (Indicator)                        False
# Emergent Herbaceous Wetlands (Indicator)        False
#                                                 mean  lower_5  upper_95  \
# Winter Wheat (Indicator)                      -0.028   -0.048    -0.012
# Dry Beans (Indicator)                         -0.054   -0.093    -0.007
# Double Crop Winter Wheat/Soybeans (Indicator) -0.062   -0.125    -0.016
# Rice (Indicator)                               0.099   -0.004     0.198
# Corn (Indicator)                               0.036   -0.034     0.110
# Cotton (Indicator)                             0.024   -0.132     0.196
# Flaxseed (Indicator)                           0.019   -0.037     0.073
# Other Small Grains (Indicator)                 0.015   -0.028     0.044
# Alfalfa (Indicator)                            0.008   -0.016     0.039
# Potatoes (Indicator)                           0.003   -0.036     0.030
# Durum Wheat (Indicator)                        0.003   -0.413     0.469
# Barley (Indicator)                             0.002   -0.031     0.036
# Other Crops (Indicator)                       -0.002   -0.041     0.038
# Sunflower (Indicator)                         -0.005   -0.066     0.042
# Canola (Indicator)                            -0.007   -0.087     0.094
# Oats (Indicator)                              -0.007   -0.039     0.010
# Peas (Indicator)                              -0.012   -0.106     0.027
# Sorghum (Indicator)                           -0.016   -0.089     0.041
# Soybeans (Indicator)                          -0.027   -0.127     0.033
# Lentils (Indicator)                           -0.041   -0.365     0.150
# Spring Wheat (Indicator)                      -0.050   -0.170     0.029
# Sugarbeets (Indicator)                        -0.090   -0.206     0.174
#
#                                                significant
# Winter Wheat (Indicator)                              True
# Dry Beans (Indicator)                                 True
# Double Crop Winter Wheat/Soybeans (Indicator)         True
# Rice (Indicator)                                     False
# Corn (Indicator)                                     False
# Cotton (Indicator)                                   False
# Flaxseed (Indicator)                                 False
# Other Small Grains (Indicator)                       False
# Alfalfa (Indicator)                                  False
# Potatoes (Indicator)                                 False
# Durum Wheat (Indicator)                              False
# Barley (Indicator)                                   False
# Other Crops (Indicator)                              False
# Sunflower (Indicator)                                False
# Canola (Indicator)                                   False
# Oats (Indicator)                                     False
# Peas (Indicator)                                     False
# Sorghum (Indicator)                                  False
# Soybeans (Indicator)                                 False
# Lentils (Indicator)                                  False
# Spring Wheat (Indicator)                             False
# Sugarbeets (Indicator)                               False

# %% [markdown]
# #### Plot of spatial effect

# %%
from matplotlib.colors import Normalize
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np

plt.figure(figsize=(12, 7))

# Create a map with appropriate projection
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_longitude=-96, central_latitude=39))

# Add state boundaries and coastlines
ax.add_feature(cfeature.STATES, edgecolor='gray', linewidth=0.5)
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)

# Create colormap for spatial effects
norm = Normalize(vmin=-2, vmax=2)

# Get spatial effects values from the trace
spatial_effects = trace.posterior['f'].mean(dim=['chain', 'draw']).values

# Create a copy of the GeoDataFrame with the spatial effect values
plot_gdf = final_gdf[is_used].copy()
plot_gdf['spatial_effect'] = spatial_effects

# Create scatter plot with centroids
scatter = ax.scatter(
    final_gdf.centroid.x[is_used], final_gdf.centroid.y[is_used], 
    c=spatial_effects,
    cmap="BrBG",
    norm=norm,
    s=3,  # Size of points
    alpha=0.7,
    transform=ccrs.PlateCarree()
)

# Add colorbar
cbar = plt.colorbar(scatter, ax=ax, orientation='vertical', pad=0.02)
cbar.set_label("Estimated effect (kT N / km$^2$ / year)")

# Set title and extent
plt.title("HSGP Spatial Random Effect")
ax.set_extent([-125, -66, 24, 50], crs=ccrs.PlateCarree())  # Continental US extent

# Save the figure
if SAVE_FIGURES:
    plt.savefig(VISUALS_DIR / 'spatial_effect_map.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1973035/395001757.py:27: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   final_gdf.centroid.x[is_used], final_gdf.centroid.y[is_used],

# %%
trace.posterior.beta.mean(axis=(0,1,2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 trace.posterior.beta.mean(axis=(0,1,2))
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/xarray/core/_aggregations.py:2982, in DataArrayAggregations.mean(self, dim, skipna, keep_attrs, **kwargs)
#    2907 def mean(
#    2908     self,
#    2909     dim: Dims = None,
#    (...)
#    2913     **kwargs: Any,
#    2914 ) -> Self:
#    2915     """
#    2916     Reduce this DataArray's data by applying ``mean`` along some dimension(s).
#    2917
#    (...)
#    2980     array(nan)
#    2981     """
# -> 2982     return self.reduce(
#    2983         duck_array_ops.mean,
#    2984         dim=dim,
#    2985         skipna=skipna,
#    2986         keep_attrs=keep_attrs,
#    2987         **kwargs,
#    2988     )
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/xarray/core/dataarray.py:3883, in DataArray.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    3839 def reduce(
#    3840     self,
#    3841     func: Callable[..., Any],
#    (...)
#    3847     **kwargs: Any,
#    3848 ) -> Self:
#    3849     """Reduce this array by applying `func` along some dimension(s).
#    3850
#    3851     Parameters
#    (...)
#    3880         summarized data and the indicated dimension(s) removed.
#    3881     """
# -> 3883     var = self.variable.reduce(func, dim, axis, keep_attrs, keepdims, **kwargs)
#    3884     return self._replace_maybe_drop_dims(var)
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/xarray/core/variable.py:1654, in Variable.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    1647 keep_attrs_ = (
#    1648     _get_keep_attrs(default=False) if keep_attrs is None else keep_attrs
#    1649 )
#    1651 # Note that the call order for Variable.mean is
#    1652 #    Variable.mean -> NamedArray.mean -> Variable.reduce
#    1653 #    -> NamedArray.reduce
# -> 1654 result = super().reduce(
#    1655     func=func, dim=dim, axis=axis, keepdims=keepdims, **kwargs
#    1656 )
#    1658 # return Variable always to support IndexVariable
#    1659 return Variable(
#    1660     result.dims, result._data, attrs=result._attrs if keep_attrs_ else None
#    1661 )
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/xarray/namedarray/core.py:919, in NamedArray.reduce(self, func, dim, axis, keepdims, **kwargs)
#     915     if isinstance(axis, tuple) and len(axis) == 1:
#     916         # unpack axis for the benefit of functions
#     917         # like np.argmin which can't handle tuple arguments
#     918         axis = axis[0]
# --> 919     data = func(self.data, axis=axis, **kwargs)
#     920 else:
#     921     data = func(self.data, **kwargs)
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/xarray/core/duck_array_ops.py:757, in mean(array, axis, skipna, **kwargs)
#     755     return _to_pytimedelta(mean_timedeltas, unit="us") + offset
#     756 else:
# --> 757     return _mean(array, axis=axis, skipna=skipna, **kwargs)
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/xarray/core/duck_array_ops.py:510, in _create_nan_agg_method.<locals>.f(values, axis, skipna, **kwargs)
#     508     with warnings.catch_warnings():
#     509         warnings.filterwarnings("ignore", "All-NaN slice encountered")
# --> 510         return func(values, axis=axis, **kwargs)
#     511 except AttributeError:
#     512     if not is_duck_dask_array(values):
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/xarray/computation/nanops.py:131, in nanmean(a, axis, dtype, out)
#     126 with warnings.catch_warnings():
#     127     warnings.filterwarnings(
#     128         "ignore", r"Mean of empty slice", category=RuntimeWarning
#     129     )
# --> 131     return nputils.nanmean(a, axis=axis, dtype=dtype)
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/xarray/core/nputils.py:242, in _create_method.<locals>.f(values, axis, **kwargs)
#     240         result = np.float64(result)
#     241 else:
# --> 242     result = getattr(npmodule, name)(values, axis=axis, **kwargs)
#     244 return result
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1046, in nanmean(a, axis, dtype, out, keepdims, where)
#    1042     raise TypeError("If a is inexact, then out must be inexact")
#    1044 cnt = np.sum(~mask, axis=axis, dtype=np.intp, keepdims=keepdims,
#    1045              where=where)
# -> 1046 tot = np.sum(arr, axis=axis, dtype=dtype, out=out, keepdims=keepdims,
#    1047              where=where)
#    1048 avg = _divide_by_count(tot, cnt, out=out)
#    1050 isbad = (cnt == 0)
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(13,13, figsize=(104, 104), sharex=True, sharey=True)
axes = axes.ravel()

p = trace.posterior.beta.shape[-1]
xs, ys = final_gdf.centroid.x[is_used], final_gdf.centroid.y[is_used]

for i in range(3):
    axes[i].set_title(pretty_predictor_cols[i])
    axes[i].scatter(
        xs,ys, 
        c=trace.posterior.beta.values[:, :, :, i].mean(axis=(0,1)), 
        s=1, alpha=0.5, cmap='BrBG',
        vmax=1, vmin=-1
    )
    axes[i].axis('off')
# Out:
# /tmp/ipykernel_1973035/963213658.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   xs, ys = final_gdf.centroid.x[is_used], final_gdf.centroid.y[is_used]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 11
#       7 for i in range(3):
#       8     axes[i].set_title(pretty_predictor_cols[i])
#       9     axes[i].scatter(
#      10         xs,ys,
# ---> 11         c=trace.posterior.beta.values[:, :, :, i].mean(axis=(0,1)),
#      12         s=1, alpha=0.5, cmap='BrBG',
#      13         vmax=1, vmin=-1
#      14     )
#      15     axes[i].axis('off')
#
# File /mnt/m2ssd/data/Dropbox/research/motives/motives-wq-modeling/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:118, in _mean(a, axis, dtype, out, keepdims, where)
#     115         dtype = mu.dtype('f4')
#     116         is_float16_result = True
# --> 118 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     119 if isinstance(ret, mu.ndarray):
#     120     with _no_nep50_warning():
#
# KeyboardInterrupt:

# %%
from matplotlib.colors import Normalize
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np

plt.figure(figsize=(12, 7))

# Create a map with appropriate projection
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_longitude=-96, central_latitude=39))

# Add state boundaries and coastlines
ax.add_feature(cfeature.STATES, edgecolor='gray', linewidth=0.5)
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)

# Create colormap for spatial effects
norm = Normalize(vmin=-2, vmax=2)

# Get spatial effects values from the trace
spatial_effects = trace.posterior['f'].mean(dim=['chain', 'draw']).values

# Create a copy of the GeoDataFrame with the spatial effect values
plot_gdf = final_gdf[is_used].copy()
plot_gdf['spatial_effect'] = spatial_effects

# Create scatter plot with centroids
scatter = ax.scatter(
    final_gdf.centroid.x[is_used], final_gdf.centroid.y[is_used], 
    c=spatial_effects,
    cmap="BrBG",
    norm=norm,
    s=3,  # Size of points
    alpha=0.7,
    transform=ccrs.PlateCarree()
)

# Add colorbar
cbar = plt.colorbar(scatter, ax=ax, orientation='vertical', pad=0.02)
cbar.set_label("Estimated effect (kT N / km$^2$ / year)")

# Set title and extent
plt.title("HSGP Spatial Random Effect")
ax.set_extent([-125, -66, 24, 50], crs=ccrs.PlateCarree())  # Continental US extent

# Save the figure
if SAVE_FIGURES:
    plt.savefig(VISUALS_DIR / 'spatial_effect_map.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Bayesian regression $R^2$ calculation

# %%
ylims = (y.min(), y.max())
xlims = (y.min(), y.max())

y_used = y[is_used]

# Calculate predictions without spatial effect
# Extract the spatial effect from the trace
spatial_effect = trace.posterior.f.mean(dim=['chain', 'draw']).values
mu_estimate = trace.posterior.mu.mean(dim=['chain', 'draw']).values

final_gdf_subset = final_gdf_subset.assign(residual=y_used - mu_estimate)

# Calculate R² for the full model
y_pred = mu_estimate
r_squared = 1 - np.var(y_used - y_pred) / np.var(y)
print(f"Full model R²: {r_squared:.4f}")

# Subtract spatial effect from full predictions to get predictions without spatial component
y_pred_no_spatial = mu_estimate - spatial_effect
r_squared_no_spatial = 1 - np.var(y_used - y_pred_no_spatial) / np.var(y_used)
print(f"R² without spatial effect: {r_squared_no_spatial:.4f}")

# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 3), sharey=True)

# Plot full model predictions
axes[0].hexbin(y_used, y_pred, cmap="bone_r", bins='log', gridsize=50)
axes[0].plot([y_used.min(), y_used.max()], [y_used.min(), y_used.max()], 'k', lw=1, label='Ideal Fit')
axes[0].set_xlabel('True Values')
axes[0].set_ylabel('Predicted Values')
axes[0].text(x=0.05, y=0.95, s=f"R² = {r_squared:.3f}", transform=axes[0].transAxes,
             fontsize=12, verticalalignment='top')

# Plot predictions without spatial effect
axes[1].hexbin(y_used, y_pred_no_spatial, bins='log', cmap="bone_r", gridsize=50)
axes[1].plot([y_used.min(), y_used.max()], [y_used.min(), y_used.max()], 'k', lw=1, label='Ideal Fit')
axes[1].set_xlabel('True Values')
axes[1].set_ylabel('Predicted Values')
axes[1].text(x=0.05, y=0.95,s= f"R² = {r_squared_no_spatial:.3f}", transform=axes[1].transAxes,
            fontsize=12, verticalalignment='top')

plt.tight_layout()
plt.savefig(VISUALS_DIR / 'prediction_comparison.png', dpi=300)
plt.show()

# Calculate the proportion of variance explained by spatial effect
spatial_contribution = r_squared - r_squared_no_spatial
if SAVE_FIGURES:
    print(f"Proportion of variance explained by spatial effect: {spatial_contribution:.4f} ({spatial_contribution/r_squared:.1%} of total R²)")
# Out:
# Full model R²: 0.9410
# R² without spatial effect: 0.7649

# %% [markdown]
# ### Plot of network overlaid on residuals

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.pyplot as plt
import cartopy.feature as cfeature
import cartopy.crs as ccrs
import numpy as np
import matplotlib.patches as mpatches

# Define the bounding box
bottom_lat = 38
top_lat = 39
left_lon = -86
right_lon = -83

# Filter the GeoDataFrame to the bounding box
# Fixing the slice syntax
final_gdf_bbox = final_gdf_subset.cx[left_lon:right_lon, bottom_lat:top_lat]

# Plot the residuals
fig = plt.figure(figsize=(20, 8))
ax = fig.add_subplot(111)

# Plot the GeoDataFrame
final_gdf_bbox.plot(
    ax=ax,
    column='residual',
    cmap='RdBu_r',
    legend=True,
    edgecolor='black',
    linewidth=0.1,
    alpha=0.9,
    vmin=-1,
    vmax=1,
    legend_kwds={'label': "Residuals (kT N / km² / year)"},
)
ax.set_title("Spatial distribution of residuals in relation to stream network")

# Get catchments in the bounding box
is_in_bbox = final_gdf.huc12.isin(final_gdf_bbox.huc12)
W_bbox = W[is_in_bbox.values][:, is_in_bbox.values]

# Get centroids of catchments in the bounding box
centroids_x, centroids_y = final_gdf_bbox.centroid.x.values, final_gdf_bbox.centroid.y.values

# Plot the stream network connections
for row, col in zip(*W_bbox.nonzero()):
    pt_x, pt_y = centroids_x[row], centroids_y[row]
    x_end, y_end = centroids_x[col], centroids_y[col]
    
    # Draw line between connected catchments
    ax.plot(
        [pt_x, x_end], [pt_y, y_end],  # Fixed: separate x and y coordinates into lists
        color='k', linewidth=0.5
    )
    
    # Add markers at catchment centroids
    ax.plot(pt_x, pt_y, marker='o', markersize=1.5, color='k')
    
    # Add arrow annotation
    ax.annotate("", xy=(x_end, y_end), xytext=(pt_x, pt_y),
            arrowprops=dict(arrowstyle="->", linewidth=0.5, alpha=0.7))
    
ax.axis('off')

# Create the inset map with cartopy projection
# Create a new figure for the inset to avoid projection conflicts
inset_fig = plt.figure(figsize=(2, 2))
inset_ax = inset_fig.add_subplot(111, projection=ccrs.AlbersEqualArea(
    central_longitude=-96, central_latitude=39))

# Add features to the inset map
inset_ax.add_feature(cfeature.STATES.with_scale('110m'), edgecolor='gray', linewidth=0.5)
inset_ax.add_feature(cfeature.COASTLINE.with_scale('110m'), linewidth=0.5)

# Set extent for USA map
inset_ax.set_extent([-125, -66, 24, 50], crs=ccrs.PlateCarree())

# Draw a rectangle showing the extent of the main map
lon_min, lon_max, lat_min, lat_max = left_lon, right_lon, bottom_lat, top_lat
rect = mpatches.Rectangle(
    (lon_min, lat_min), lon_max - lon_min, lat_max - lat_min,
    facecolor='none', edgecolor='red', linewidth=1.5, 
    transform=ccrs.PlateCarree())
inset_ax.add_patch(rect)

# Remove axis ticks and labels from the inset
inset_ax.set_xticks([])
inset_ax.set_yticks([])
inset_path = VISUALS_DIR / 'usa_inset.png'
# Save the inset figure
inset_fig.savefig(inset_path, dpi=300, bbox_inches='tight', transparent=True)
plt.close(inset_fig)

# Add the inset as an image to the main figure
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
inset_img = plt.imread(inset_path)
imagebox = OffsetImage(inset_img, zoom=0.5)
ab = AnnotationBbox(imagebox, (0.05, 0.05), frameon=True, 
                    xycoords='axes fraction')
ax.add_artist(ab)

if SAVE_FIGURES:
    plt.savefig(VISUALS_DIR / 'bbox_residuals_with_stream_network.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1973035/1296674298.py:42: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids_x, centroids_y = final_gdf_bbox.centroid.x.values, final_gdf_bbox.centroid.y.values
